# %% [markdown]
# ### Welcome to this Video Games Exploratory Data Analysis Kernel 🎮👋

# %% [markdown]
# Выполнил: Гусев Е.А.  4941102/10701
#
# Database: https://www.kaggle.com/datasets/thedevastator/discovering-hidden-trends-in-global-video-games
#
# Этот скрипт выполняет базовый анализ, визуализацию данных о статистических исследованиях продаж видеоигр на различных платформах, жанрах и регионах, включая глобальный рейтинг, название, платформу, год выпуска, жанр, информацию об издателе, информацию о продажах в Северной Америке, Европе, Японии и остальном мире, а также общую сумму всех продаж по всему миру.
#
# Создадим таблицы для анализа, импортируя необходимые модули.

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('/content/Video Games Sales.csv', index_col='index')

# %%
df
# Out:
#        Rank                        Game Title Platform    Year         Genre  \
# index
# 0         1                        Wii Sports      Wii  2006.0        Sports
# 1         2                 Super Mario Bros.      NES  1985.0      Platform
# 2         3                    Mario Kart Wii      Wii  2008.0        Racing
# 3         4                 Wii Sports Resort      Wii  2009.0        Sports
# 4         5                            Tetris       GB  1989.0        Puzzle
# ...     ...                               ...      ...     ...           ...
# 1902   1903  Lizzie McGuire 2: Lizzie Diaries      GBA  2004.0        Action
# 1903   1904              Xenoblade Chronicles      Wii  2010.0  Role-Playing
# 1904   1905                     SingStar Abba      PS3  2008.0          Misc
# 1905   1906    FIFA Soccer World Championship      PS2  2000.0        Sports
# 1906   1907        WWE SmackDown vs. Raw 2011     X360  2010.0      Fighting
#
# ...

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Гистограмма для визуализации распределения обзоров видеоигр

# %%
fig = px.histogram(df, x="Review")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Есть несколько причин, по которым отзывы о видеоиграх могут показаться высокими:
#
# 1) Рецензентов часто выбирают разработчики игр или издатели, и они с большей вероятностью дадут благоприятный отзыв, чтобы поддерживать хорошие отношения с компанией.
#
# 2) Рецензенты могут быть поклонниками жанра игры или разработчика, и поэтому с большей вероятностью дадут положительный отзыв.
#
# 3) Рецензенты, возможно, захотят избежать негативной реакции со стороны поклонников игры.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Точечный график, показывающий корреляцию между продажами игры и годом ее выпуска

# %%
fig = px.scatter(df, x="Year", y="Rank", color="Platform",
                 hover_name="Game Title", size_max=20, trendline="ols", trendline_scope="overall")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Существует ряд факторов, которые объясняют, почему старые игры, как правило, продавались дороже, чем новые. Некоторые возможные объяснения включают:
#
# 1) Изменения на рынке:
#
# Индустрия видеоигр значительно выросла за эти годы, и сегодня у потребителей гораздо больше возможностей, чем было в прошлом. Это может затруднить любой отдельной игре выделиться и хорошо продаваться.
#
# 2) Изменения в игровых привычках:
#
# То, как люди играют в игры, также изменилось с течением времени. Например, распространение мобильных игр привело к тому, что многие люди играют в более короткие и казуальные игры, а не в более длинные и захватывающие консольные или компьютерные игры.
#
# 3) Изменения в моделях распространения:
#
# Способ продажи игр также претерпел изменения. В прошлом большинство игр продавались в физической форме в розничных магазинах. Сегодня многие игры продаются в цифровом виде через онлайн-маркетплейсы или службы подписки. Это может облегчить игрокам поиск и покупку новых игр, но также может затруднить выделение отдельных игр.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Точечный график, показывающий корреляцию между отзывами и продажами видеоигры

# %%
fig = px.scatter(df, x="Rank", y="Review", color="Platform",
                 hover_name="Game Title", size_max=20, trendline="ols", trendline_scope="overall")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Игры, получающие хорошие отзывы, как правило, продаются лучше, чем те, которые получают плохие отзывы. Есть ряд причин, по которым это может иметь место:
#
# 1) Сарафанное радио:
#
# Хорошие отзывы могут помочь распространить информацию об игре и побудить людей попробовать ее. Положительные отзывы из надежных источников, таких как профессиональные рецензенты или влиятельные лица, могут быть особенно эффективными для убеждения людей приобрести игру.
#
# 2) Качество:
#
# В целом, игры, получающие хорошие отзывы, скорее всего, будут более качественными, чем те, которые получают плохие отзывы. Это может быть особенно важно для игроков, которые рассматривают возможность покупки игры, поскольку они хотят быть уверены, что получают хорошее соотношение цены и качества за свои деньги.
#
# 3) Доверие:
#
# Хорошие отзывы могут помочь укрепить доверие к игре и разработчику или издателю, стоящему за ней. Это может быть особенно важно для игроков, которые рассматривают возможность покупки игры у незнакомого им разработчика или издателя.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Линейный график, показывающий корреляцию года публикации видеоигры и их среднего отзыва

# %%
line_chart_df = df.groupby(['Year'])["Review"].mean().reset_index(name='Mean Review')

fig = px.line(line_chart_df, x="Year", y="Mean Review", markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Нельзя найти четкой закономерности между годом выпуска видеоигры и ее обзорами. Они, как правило, группируются в диапазоне 78-82.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Линейный график, показывающий количество видеоигр, опубликованных для каждой консоли с течением времени

# %%
line_chart_df = df.groupby(['Platform','Year']).size().reset_index(name='count')

fig = px.line(line_chart_df, x="Year", y="count", color='Platform', markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Очевидно, что ни одна консоль не выдержала испытания временем. Когда выходят консоли нового поколения, производители видеоигр выпускают игры для этих новых платформ и прекращают выпуск игр для старых.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Линейный график, показывающий количество видеоигр, выпущенных разными издателями с течением времени

# %%
line_chart_df = df.groupby(['Publisher','Year']).size().reset_index(name='count')

fig = px.line(line_chart_df, x="Year", y="count", color='Publisher', markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Существует ряд причин, по которым издатели видеоигр могут выпускать больше игр каждый год, как показано на графике выше. Вот лишь некоторые из них:
#
# 1) Чтобы оставаться конкурентоспособным:
#
# Индустрия видеоигр отличается высокой конкуренцией, и издатели могут выпускать больше игр, чтобы оставаться актуальными и не отставать от своих конкурентов. Регулярно выпуская новые игры, издатель может оставаться в центре внимания общественности и привлекать новых игроков к своим играм.
#
# 2) Чтобы воспользоваться преимуществами новых технологий:
#
# По мере появления новых технологий, таких как новые игровые консоли или гарнитуры виртуальной реальности, издатели могут выпускать больше игр, чтобы воспользоваться преимуществами этих платформ и охватить новую аудиторию.
#
# 3) Для удовлетворения потребительского спроса:
#
# Потребители также могут стимулировать тенденцию к выпуску большего количества игр с каждым годом. С распространением онлайн-маркетплейсов и сервисов подписки игрокам стало проще находить и приобретать новые игры. В результате может возникнуть больший спрос на новые игры со стороны игроков, что может побудить издателей выпускать больше названий.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Линейный график, показывающий количество видеоигр, выпущенных по жанрам с течением времени

# %%
line_chart_df = df.groupby(['Genre','Year']).size().reset_index(name='count')

fig = px.line(line_chart_df, x="Year", y="count", color='Genre', markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Существует ряд причин, по которым определенные жанры видеоигр могут стать более популярными, в то время как другие могут застопориться. Некоторые возможные объяснения включают:
#
# 1) Изменения в потребительских предпочтениях:
#
# Потребительские предпочтения могут меняться с течением времени, и в результате определенные жанры могут стать более или менее популярными.
#
# 2) Изменения в технологиях:
#
# Возможности игровых технологий также могут влиять на популярность различных жанров. Например, растущий реализм и погружение консолей могут сделать определенные жанры, такие как приключенческие игры или шутеры, более привлекательными для игроков.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Линейные и столбчатые диаграммы, показывающие распределение рынка видеоигр по регионам во времени

# %%
global_df = df.groupby(['Year'])["Global"].sum().reset_index(name='sum')
global_df["Region"] = "Global"
japan_df = df.groupby(['Year'])["Japan"].sum().reset_index(name='sum')
japan_df["Region"] = "Japan"
na_df = df.groupby(['Year'])["North America"].sum().reset_index(name='sum')
na_df["Region"] = "North America"
europe_df = df.groupby(['Year'])["Europe"].sum().reset_index(name='sum')
europe_df["Region"] = "Europe"
row_df = df.groupby(['Year'])["Rest of World"].sum().reset_index(name='sum')
row_df["Region"] = "Rest of World"

line_chart_df = global_df.append(japan_df)
line_chart_df = line_chart_df.append(na_df)
line_chart_df = line_chart_df.append(europe_df)
line_chart_df = line_chart_df.append(row_df).reset_index()

fig = px.line(line_chart_df, x="Year", y="sum", color='Region', markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
bar_chart_df = line_chart_df[line_chart_df["Region"] != "Global"]
fig = px.bar(bar_chart_df, x="Year", y="sum", color='Region', text_auto=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# В целом, тенденция игровой индустрии заключалась в росте на протяжении последних 30 лет. Однако существует ряд причин, по которым рынок видеоигр может расти быстрее в некоторых регионах, таких как Северная Америка или Европа, по сравнению с другими, такими как Япония. Некоторые возможные объяснения включают:
#
# 1) Большая численность населения:
#
# Население Северной Америки и Европы больше, чем в Японии, что может облегчить компаниям, производящим видеоигры, охват более широкой аудитории и продажу большего количества игр.
#
# 2) Более высокая покупательная способность:
#
# Потребители в Северной Америке и Европе также могут иметь больший располагаемый доход, что может повысить их вероятность покупки видеоигр.
#
# 3) Различные культурные предпочтения:
#
# Также могут существовать культурные различия, которые влияют на популярность видеоигр в разных регионах. Например, японские игроки могут иметь разные предпочтения с точки зрения игровых жанров или стилей, что может повлиять на общий рынок видеоигр в Японии.
#
# 4) Различные модели дистрибуции:
#
# Способ продажи и распространения игр также может оказывать влияние на рынок. Например, если цифровая дистрибуция будет более распространена в Северной Америке и Европе, это может облегчить игрокам поиск и покупку новых игр, что может стимулировать рынок.
#
# С другой стороны, в регионах остального мира, таких как Юго-Восточная Азия или Китай, наблюдался самый быстрый рост, главным образом потому, что в 1983-2012 годах в них было наибольшее количество населения, достигшего среднего класса, а это означает, что теперь больше людей могли позволить себе видеоигры.
